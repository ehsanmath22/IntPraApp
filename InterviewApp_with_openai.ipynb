# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
# Out:
# True

# %%
# Instantiate the client, pointing it at OpenRouter.
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    max_retries=2,
)

# %%
SYSTEM_PROMPT = (
    "You are an expert interview coach. When given a question or topic, "
    "provide a clear, structured, and practical answer to help the user "
    "prepare for job interviews. Include a strong sample answer where "
    "appropriate, key points to hit, and a short tip on delivery. "
    "Keep it focused and easy to read."
)

# %%
def ask(question: str) -> str:
    completion = client.chat.completions.create(
        model="openai/gpt-4o-mini",
        temperature=0,
        max_tokens=None,
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": f"Question:{question}"},
        ],
    )
    return completion.choices[0].message.content

# %%
response = ask("who are you")
print(response)
# Out:
# **Answer Structure:**
#
# 1. **Introduction**: Briefly state your name and current position or status.
# 2. **Professional Background**: Summarize your relevant work experience and skills.
# 3. **Key Achievements**: Highlight a couple of significant accomplishments.
# 4. **Personal Touch**: Share a bit about your interests or values that relate to the job.
# 5. **Closing**: Connect your background to the role you’re applying for.
#
# **Sample Answer:**
#
# "Hello, my name is Jane Doe. I am a marketing professional with over five years of experience in digital marketing and brand management. In my previous role at XYZ Corp, I successfully led a campaign that increased our social media engagement by 150% within six months, which significantly boosted our online sales.
#
# I have a strong background in data analysis and content creation, which allows me to develop strategies that resonate with target audiences. I am passionate about using innovative marketing techniques to drive brand awareness and customer loyalty.
#
# Outside of work, I enjoy volunteering for local non-profits, where I help them enhance their online presence. I believe that my skills in digital marketing and my commitment to community engagement align well with your company’s mission to connect with customers meaningfully. I’m excited about the opportunity to contribute to your team."
#
# **Key Points to Hit:**
# - Your name and current role.
# - Relevant experience and skills.
# - Notable achievements that demonstrate your capabilities.
# - Personal interests that align with the company’s values.
# - A connection to the job you’re applying for.
#
# **Tip on Delivery:**
# Practice your introduction to ensure it flows naturally. Maintain eye contact and use a confident tone to convey enthusiasm about your background and the opportunity.

# %%
print(ask("what are LLMs ?"))
# Out:
# **Understanding LLMs (Large Language Models)**
#
# **Key Points to Hit:**
# 1. **Definition**: LLMs are a type of artificial intelligence model designed to understand and generate human-like text based on the input they receive.
# 2. **Functionality**: They are trained on vast amounts of text data, allowing them to predict the next word in a sentence, answer questions, summarize information, and more.
# 3. **Applications**: Commonly used in chatbots, content creation, translation services, and even coding assistance.
# 4. **Examples**: Notable examples include OpenAI's GPT-3 and GPT-4, Google's BERT, and Meta's LLaMA.
# 5. **Limitations**: While powerful, LLMs can sometimes produce incorrect or nonsensical answers and may reflect biases present in their training data.
#
# **Sample Answer:**
# "Large Language Models, or LLMs, are advanced AI systems that are designed to process and generate human-like text. They work by analyzing vast datasets of written language, which allows them to understand context, grammar, and even nuances in meaning. For instance, models like OpenAI's GPT-4 can engage in conversations, write essays, and even assist in coding tasks. However, it's important to note that while they are incredibly powerful, they can also produce inaccurate information and may carry biases from their training data. Their applications range from customer service chatbots to content generation tools, making them versatile assets in various industries."
#
# **Tip on Delivery:**
# When discussing LLMs, maintain a confident and clear tone. Use simple language to explain complex concepts, and be prepared to answer follow-up questions to demonstrate your understanding.

# %%
print(ask("Where you see yourself in next 5 years ?"))
# Out:
# **Answer Structure:**
#
# 1. **Career Goals**: Outline your professional aspirations.
# 2. **Skill Development**: Mention the skills you plan to acquire.
# 3. **Contribution to the Company**: Explain how you intend to contribute to the organization.
# 4. **Flexibility**: Acknowledge that plans may evolve.
#
# **Sample Answer:**
#
# "In the next five years, I see myself growing into a leadership role within this organization. I aim to deepen my expertise in [specific area related to the job, e.g., project management, data analysis], and I plan to pursue relevant certifications to enhance my skills. I want to contribute to the team by leading projects that drive innovation and efficiency, ultimately helping the company achieve its strategic goals. I understand that the industry is constantly evolving, so I remain open to new opportunities and challenges that may arise along the way."
#
# **Key Points to Hit:**
#
# - Be specific about your career goals.
# - Highlight your commitment to professional development.
# - Show alignment with the company’s objectives.
# - Express adaptability to change.
#
# **Tip on Delivery:**
#
# Speak confidently and maintain eye contact. Use a positive tone to convey enthusiasm about your future and the potential to grow within the company.
